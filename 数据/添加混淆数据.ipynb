# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Water/Aquifer_Petrignano.csv")
df.head()
# Out:
#          date  rainfall  depth_to_groundwater  temperature  drainage_volume  \
# 0  2009.01.01       0.0                -31.14          5.2       -24530.688
# 1  2009.01.02       0.0                -31.11          2.3       -28785.888
# 2  2009.01.03       0.0                -31.07          4.4       -25766.208
# 3  2009.01.04       0.0                -31.05          0.8       -27919.296
# 4  2009.01.05       0.0                -31.01         -1.9       -29854.656
#
#    river_hydrometry
# 0               2.4
# 1               2.5
# 2               2.4
# 3               2.4
# 4               2.3

# %%
df2 = pd.read_csv("Water/Aquifer_Doganella.csv")
df2.head()
# Out:
#          Date  Rainfall_Monteporzio  Rainfall_Velletri  \
# 0  01/01/2004                   0.0                0.0
# 1  02/01/2004                   0.2                0.8
# 2  03/01/2004                   0.0                0.0
# 3  04/01/2004                   0.0                0.0
# 4  05/01/2004                   0.2                0.0
#
#    Depth_to_Groundwater_Pozzo_1  Depth_to_Groundwater_Pozzo_2  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Depth_to_Groundwater_Pozzo_3  Depth_to_Groundwater_Pozzo_4  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# ...

# %%
df22 = df2.iloc[-4199:,3]
df22.fillna(0, inplace=True)
df22
# Out:
# 1827     0.00
# 1828     0.00
# 1829     0.00
# 1830     0.00
# 1831     0.00
#         ...
# 6021   -50.32
# 6022   -50.32
# 6023   -50.32
# 6024   -50.32
# 6025   -50.78
# Name: Depth_to_Groundwater_Pozzo_1, Length: 4199, dtype: float64

# %%
df['Depth_to_Groundwater_Pozzo_1'] = df22
df.fillna(0, inplace=True)
df.to_csv("Water/Aquifer_Petrignano1.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("Water/Aquifer_Petrignano copy.csv")
df.head()
df.fillna(0, inplace=True)
df.to_csv("Water/Aquifer_Petrignano2.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 6 df = pd.read_csv("Water/Aquifer_Petrignano copy.csv")
#       7 df.head()
#       8 df.fillna(0, inplace=True)
#
# ...

# %%
df
# Out:
#                      date  rainfall  depth_to_groundwater  temperature  \
# 0     01.01.2009 00:00:00       0.0                -31.14          5.2
# 1     01.02.2009 00:00:00       0.0                -31.11          2.3
# 2     01.03.2009 00:00:00       0.0                -31.07          4.4
# 3     01.04.2009 00:00:00       0.0                -31.05          0.8
# 4     01.05.2009 00:00:00       0.0                -31.01         -1.9
# ...                   ...       ...                   ...          ...
# 4194  06.26.2020 00:00:00       0.0                -25.07         25.7
# 4195  06.27.2020 00:00:00       0.0                -25.11         26.2
# 4196  06.28.2020 00:00:00       0.0                -25.19         26.9
# 4197  06.29.2020 00:00:00       0.0                -25.18         26.9
# 4198  06.30.2020 00:00:00       0.0                -25.25         27.3
#
#       drainage_volume  river_hydrometry
# 0          -24530.688               2.4
# ...
